# %%
from main import Plot
from IPython.display import Image, display

plot_instance = Plot('deviation.json')

paths = plot_instance.draw_plots()

for path in paths:
    display(Image(filename=path))
